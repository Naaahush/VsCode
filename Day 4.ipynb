# %%
#Importing Libraries
import pandas  as pd
import numpy  as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Reading the file
df = pd.read_csv('C:\VsCode\Credit card transactions - India - Simple (1).csv')

# %%
#printing the DataFrame
df
# Out:
#        index                   City       Date  Card Type Exp Type Gender  \
# 0          0           Delhi, India  29-Oct-14       Gold    Bills      F
# 1          1  Greater Mumbai, India  22-Aug-14   Platinum    Bills      F
# 2          2       Bengaluru, India  27-Aug-14     Silver    Bills      F
# 3          3  Greater Mumbai, India  12-Apr-14  Signature    Bills      F
# 4          4       Bengaluru, India   5-May-15       Gold    Bills      F
# ...      ...                    ...        ...        ...      ...    ...
# 26047  26047         Kolkata, India  22-Jun-14     Silver   Travel      F
# 26048  26048            Pune, India   3-Aug-14  Signature   Travel      M
# 26049  26049       Hyderabad, India  16-Jan-15     Silver   Travel      M
# 26050  26050          Kanpur, India  14-Sep-14     Silver   Travel      M
# 26051  26051       Hyderabad, India  19-Oct-13  Signature    Bills      M
#
#        Amount
# 0       82475
# 1       32555
# 2      101738
# 3      123424
# ...

# %%
#using info() to understand columns.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26052 entries, 0 to 26051
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      26052 non-null  int64
#  1   City       26052 non-null  object
#  2   Date       26052 non-null  object
#  3   Card Type  26052 non-null  object
#  4   Exp Type   26052 non-null  object
#  5   Gender     26052 non-null  object
#  6   Amount     26052 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 1.4+ MB

# %%
#to analyze numeric columns
df.describe()
# Out:
#               index         Amount
# count  26052.000000   26052.000000
# mean   13025.500000  156411.537425
# std     7520.708943  103063.254287
# min        0.000000    1005.000000
# 25%     6512.750000   77120.250000
# 50%    13025.500000  153106.500000
# 75%    19538.250000  228050.000000
# max    26051.000000  998077.000000

# %% [markdown]
# ### Observation: - Index is useless column.
# There is only amount column which is purely numerical.

# %%
#Droppping index column
df.drop(['index'],axis=1,inplace=True)

# %%
#checkinf for null values

df.isnull().sum()
# Out:
# City         0
# Date         0
# Card Type    0
# Exp Type     0
# Gender       0
# Amount       0
# dtype: int64

# %% [markdown]
# ## EDA
#
# Visualizing the data for better understanding.

# %%
#plotting a barplot of card type and gender

sns.barplot(df,x='Exp Type',y='Amount',hue='Gender',palette='rocket')
# Out:
# <Axes: xlabel='Exp Type', ylabel='Amount'>

# %% [markdown]
# Observation:-
# 1. Females are using their cards more to pay the bills.
# 2. The amount getting spent on all other types from both genders is same.

# %%
#plotting a barplot

sns.barplot(df,x='Card Type',y='Amount',hue='Exp Type',palette='Paired')
# Out:
# <Axes: xlabel='Card Type', ylabel='Amount'>

# %% [markdown]
# Observation:-
#
# 1. Every type of card is getting mostly used to pay the regular bills.
# 2. Platinum card is under utilized in travel category compared to its other competitors.

# %%
sns.barplot(df,x='Gender',y='Amount',hue='Card Type',palette='rocket')
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %% [markdown]
# Observation:-
# 1. Females are using their cards for more amount more than males.
# 2. Distribution of cards types are almost same for both genders.

# %%
sns.barplot(df,x='Gender',y='Amount',hue='Exp Type',palette='rocket')
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>
